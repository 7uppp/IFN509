# %%
import pandas as pd
df1=pd.read_csv('C:\\Users\\markw\\Desktop\\IN20-SEM2\\IFN509 Data Exploration and Mining\\D1.csv')

# %%
df1.boxplot(column=['weight'])

# %%
df1.boxplot(column=['height'])

# %% [markdown]
# Common data qualities include:
# 	1) Incompleteness: where crucial pieces of information are missing
# 
# 	2) Inaccuracy: all of the information may be ‘present’ (or the data fields filled in), but it could be entered in the wrong field, spelled incorrectly, or the field contains a junk value
# 
# 	3) Inconsistency: data that should be presented with the same value / format is inconsistent
# 
# 	4) Invalidity: the fields are complete, but with data that can’t possibly be correct in that context
# 
# 	5) Redundancy: where the same data is entered multiple times but expressed in slightly different ways
# 
# 	6) Non-standard data: information that’s input using non-standard formats
#
# During the analysis process, it can be found the data quality problems including invalidity and incompleteness.
# First of all, for the weight column, the boxplot indicates there are lots of outliers over the maximum. The range of outliers are between 130kg to 180kg. Outliers in a batch of data are worthy of attention. It is very dangerous to ignore the existence of outliers. Including outliers into the calculation and analysis of data without removing them will have adverse effects on the results. Paying attention to the occurrence of outliers and analyzing the causes of them often become an opportunity to find problems and improve decision-making. As there are lots of outliers, it means the tail is more heavier and the degree of freedom is smaller, meanwhile, we should attempt to correct the data and try to find any errors in the original dataset.
#
# Then,for height column, it has a similar situation with the weight one. There are also lost of outliers but distribute under the minimum. The range of outliers are between 110cm-140cm.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
fig,axes = plt.subplots()
df1.plot(x='covid19_positive', y='risk_infection', kind='scatter',s=10**2, c='b',marker='o',ax=axes)
axes.set_xlabel('risk_infection')
axes.set_ylabel('covid19_positive')
# Out:
# Text(0, 0.5, 'covid19_positive')

# %% [markdown]
# From the graph we can see there is a strong positive relationship between covid-19 positive and risk_infection only when covid_19 positive equals 1, and for other numbers, we can not see there is any obviously relationship between those two variables.

# %%
import warnings
warnings.filterwarnings("ignore")
import missingno as msno
msno.heatmap(df1)

# %% [markdown]
# According to the heatmap, some highly correlated variable pairs can be found. Each square shows the correlation between the variables on each axis. Correlation ranges from -1 to +1. Values closer to zero means there is no linear trend between the two variables. The close to 1 the correlation is the more positively correlated they are; that is as one increases so does the other and the closer to 1 the stronger this relationship is. A correlation closer to -1 is similar, but instead of both increasing one variable will decrease as the other increases.
#
# So, the highly correlated variable pairs are as follows:
#
# 1.	insurance-worried
# 2.	insurance-transport_count
# 3.	insurance-immigrant
# 4.	insurance-race
# 5.	insurance-income
#
# 1.	Income-worried
# 2.	Income- transport_count
# 3.	Income- immigrant
# 4.	Income-race
#
#
# 1.	Race- worried
# 2.	Race- immigrant
# 3.	Race- transport_count
#
# 1.	Immigrant-worried
# 2.	Immigrant-transport_count
#
# 1.	Contacts_count-working
# 2.	Working-worried

# %%
import os
print(os.path.abspath('.'))
# Out:
# C:\Users\markw\509
